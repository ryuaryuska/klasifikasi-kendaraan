# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df_train = pd.read_csv('Data/kendaraan_train_clean.csv')
df_train.head()
# Out:
#    Jenis_Kelamin      Umur  Kode_Daerah  Sudah_Asuransi  Umur_Kendaraan  \
# 0            0.0  0.153846     0.634615             1.0             0.0
# 1            1.0  0.430769     0.750000             0.0             1.0
# 2            1.0  0.015385     0.884615             1.0             0.0
# 3            1.0  0.461538     0.673077             0.0             1.0
# 4            1.0  0.015385     0.673077             1.0             0.0
#
#    Kendaraan_Rusak     Premi  Kanal_Penjualan  Lama_Berlangganan  Tertarik
# 0              0.0  0.409000         0.932099           0.301038         0
# 1              1.0  0.367431         0.172840           0.512111         0
# 2              0.0  0.496727         0.981481           0.377163         0
# 3              1.0  0.536338         0.537037           0.636678         0
# 4              0.0  0.310270         0.932099           0.557093         0

# %%
df_test = pd.read_csv('Data/kendaraan_test_clean.csv')
df_test.head()
# Out:
#    Jenis_Kelamin      Umur  Kode_Daerah  Sudah_Asuransi  Umur_Kendaraan  \
# 0            0.0  0.446154     0.153846             0.0             0.5
# 1            1.0  0.030769     0.903846             1.0             0.0
# 2            1.0  0.061538     0.538462             1.0             0.0
# 3            1.0  0.400000     0.153846             1.0             0.5
# 4            1.0  0.230769     0.442308             0.0             0.5
#
#    Kendaraan_Rusak     Premi  Kanal_Penjualan  Lama_Berlangganan  Tertarik
# 0              1.0  0.082475         0.154321           0.467128         0
# 1              0.0  0.068822         0.932099           0.799308         0
# 2              0.0  0.200636         0.932099           0.179931         0
# 3              0.0  0.062575         0.759259           0.083045         0
# 4              1.0  0.045268         0.932099           0.757785         0

# %%
#Pengecekan jumlah dari tertarik dan tidak tertarik
fig, ax =plt.subplots(1,2,figsize=(10,5))
sns.set_theme(style='whitegrid',palette='tab10')
ax[0].set_title('Data Train')
sns.countplot(df_train['Tertarik'], ax=ax[0])
ax[1].set_title("Data Test")
sns.countplot(df_test['Tertarik'], ax=ax[1])
fig.show()
print('Data Train Tertarik Count \n', df_train['Tertarik'].value_counts())
print('Data Test Tertarik Count \n', df_test['Tertarik'].value_counts())
# Out:
# Data Train Tertarik Count
#  0    202945
# 1     27686
# Name: Tertarik, dtype: int64
# Data Test Tertarik Count
#  0    41778
# 1     5861
# Name: Tertarik, dtype: int64

# %% [markdown]
# ## Train Test Split Data

# %%
#Split data train
x_train = df_train.drop('Tertarik',axis=1)
y_train = df_train['Tertarik']
#split data test
x_test = df_test.drop('Tertarik',axis=1)
y_test = df_test['Tertarik']

print(f'x_train shape: {x_train.shape}, y_train shape: {y_train.shape}')
print(f'x_test shape: {x_test.shape}, y_test shape: {y_test.shape}')
# Out:
# x_train shape: (230631, 9), y_train shape: (230631,)
# x_test shape: (47639, 9), y_test shape: (47639,)

# %% [markdown]
# ## Classification Model

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report,f1_score,recall_score,precision_score,roc_auc_score,roc_curve,auc
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB  
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ### Mencari K Optimal Akurasi Untuk K-Nearest Neighbors

# %%
acc = []
# Will take some time
from sklearn import metrics
for i in range(1,40):
    neigh = KNeighborsClassifier(n_neighbors = i).fit(x_train,y_train)
    yhat = neigh.predict(x_test)
    acc.append(metrics.accuracy_score(y_test, yhat))
# Visualisasi Max Akurasi
plt.figure(figsize=(10,6))
plt.plot(range(1,40),acc,color = 'blue',linestyle='dashed', 
         marker='o',markerfacecolor='red', markersize=10)
plt.title('accuracy vs. K Value')
plt.xlabel('K')
plt.ylabel('Accuracy')
optimumK = acc.index(max(acc))
print("Maximum accuracy:-",max(acc),"at K =",optimumK)
# Out:
# Maximum accuracy:- 0.8757740506727681 at K = 37

# %% [markdown]
# ### Pengujian Classification

# %%
# CLass dari library pemodelan
model_lib = [
    DecisionTreeClassifier(),
    LogisticRegression(),
    KNeighborsClassifier(n_neighbors=optimumK),
    RandomForestClassifier(),
    GaussianNB()
]
# Nama Model
model_name = [
    'Decision Tree',
    'Logistic Regression',
    'K-Nearest Neighbors',
    'Random Forest Classifier',
    'Gaussian Naive Bayes'
]

# %%
def result_detail(model, model_name):
    #Training Data
    model.fit(x_train,y_train)
    # Predict Data
    predict_result = model.predict(x_test)
    print('='*50)
    # Membuat Confusion matrix untuk melihat bagaimana prediksinya
    plt.figure()
    matrix = confusion_matrix(y_test,predict_result)
    sns.heatmap(data=matrix,cmap='viridis',annot=True,fmt='.0f',annot_kws={'size':20})

    plt.title(f'Confusion Matrix {model_name}')
    plt.xlabel('Nilai Prediksi')
    plt.ylabel('Nilai Sebenarnya')
    plt.show()

    recal= recall_score(y_test,predict_result) # Melakukan Pencarian Nilai Recal
    precision = precision_score(y_test,predict_result)# Melakukan Pencarian Nilai Precision
    f1Score = f1_score(y_test,predict_result)# Melakukan Pencarian Nilai f1 score
    acc = accuracy_score(y_test,predict_result)# Melakukan Pencarian Akurasi
    rocAuc = roc_auc_score(y_test,predict_result)# Melakukan Pencarian Skor roc auc
    print(f'Model {model_name}')
    print(f'Recall\t\t : {recal}')
    print(f'Precision\t : {precision}')
    print(f'F1-Score\t : {f1Score}')
    print(f'ROC-AUC Score\t : {rocAuc}')
    print(f'Akurasi Score\t : {acc}')
    print('Classification Report: ')
    print(classification_report(y_test,predict_result)) # Library Untuk Memperlihatkan semua info baik akurasi,f1 score, dll
    return model_name, f1Score, acc, rocAuc

# %%
#Mencari curve roc
def curve_roc(model):
    fpr,tpr,_ = roc_curve(y_test,model.predict_proba(x_test)[:,1])
    return fpr,tpr
#Visualisasi curve roc
def visual_ROC(model,name,rocAuc):
    plt.title(f'ROC Curve {name}')
    fpr,tpr = (curve_roc(model))
    plt.plot(fpr,tpr, label=f'{name} : {round(rocAuc,3)}')
    plt.legend(loc='best')
    plt.plot([0,1],[0,1],'r--')
    plt.ylabel('True Prositive Rate')
    plt.xlabel('False Positif Rate')
    plt.show()

# %%
model_info = []
for model, i in zip(model_lib,model_name):
    name,  f1Score, akurasi,rocAuc = result_detail(model,i)
    visual_ROC(model,i,rocAuc)
    model_info.append([name, f1Score, akurasi, rocAuc]) # Ini semua info yang nanti akan ditapilkan kedalam dataframe untuk setiap model
# Out:
# ...
# Model Decision Tree
# Recall		 : 0.4860945231189217
# Precision	 : 0.28789409862570736
# F1-Score	 : 0.3616170590848512
# ROC-AUC Score	 : 0.6587086144246052
# Akurasi Score	 : 0.7888494720712022
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.83      0.87     41778
#            1       0.29      0.49      0.36      5861
#
#     accuracy                           0.79     47639
#    macro avg       0.60      0.66      0.62     47639
# weighted avg       0.84      0.79      0.81     47639
# ...
# Model Logistic Regression
# Recall		 : 0.001876812830574987
# Precision	 : 0.28205128205128205
# F1-Score	 : 0.0037288135593220332
# ROC-AUC Score	 : 0.5006033018147801
# Akurasi Score	 : 0.8766136988601776
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93     41778
#            1       0.28      0.00      0.00      5861
#
# ...

# %%
# Hasil info sebelumnya dimasukan kedalam data frame
df_result = pd.DataFrame(model_info, columns=['Nama_Model', 'F1_Score','Akurasi', 'Roc_Auc'])
df_result
# Out:
#                  Nama_Model  F1_Score   Akurasi   Roc_Auc
# 0             Decision Tree  0.361617  0.788849  0.658709
# 1       Logistic Regression  0.003729  0.876614  0.500603
# 2       K-Nearest Neighbors  0.029647  0.874955  0.505525
# 3  Random Forest Classifier  0.216708  0.853565  0.557430
# 4      Gaussian Naive Bayes  0.421454  0.684586  0.791712

# %%
# Melihat Akurasi untuk setiap model
fig, ax1 = plt.subplots(figsize=(15, 10))
tidy = df_result.melt(id_vars='Nama_Model').rename(columns=str.title)
sns.barplot(x='Nama_Model', y='Value', hue='Variable',palette='viridis', data=tidy, ax=ax1)
sns.despine(fig)

# %% [markdown]
# ## **Eksperimen Data Train Dengan Data Yang Masih Menggunakan Outlier**

# %%
#Input Data Eksperimen
df_train_eksperimen = pd.read_csv('Data/kendaraan_train_clean_with_outlier.csv')
df_train_eksperimen
# Out:
#         Jenis_Kelamin      Umur  Kode_Daerah  Sudah_Asuransi  Umur_Kendaraan  \
# 0                 0.0  0.153846     0.634615             1.0             0.0
# 1                 1.0  0.430769     0.750000             0.0             1.0
# 2                 1.0  0.015385     0.884615             1.0             0.0
# 3                 0.0  0.584615     0.923077             0.0             0.5
# 4                 1.0  0.461538     0.673077             0.0             1.0
# ...               ...       ...          ...             ...             ...
# 285657            0.0  0.046154     0.076923             1.0             0.0
# 285658            0.0  0.015385     0.884615             1.0             0.0
# 285659            0.0  0.046154     0.961538             1.0             0.0
# 285660            1.0  0.738462     0.134615             1.0             0.5
# 285661            1.0  0.384615     0.538462             0.0             0.5
#
# ...

# %%
#split data train dengan data eksperimen
x_train = df_train_eksperimen.drop('Tertarik',axis=1)
y_train = df_train_eksperimen['Tertarik']
#split data test
x_test = df_test.drop('Tertarik',axis=1)
y_test = df_test['Tertarik']

print(f'x_train shape: {x_train.shape}, y_train shape: {y_train.shape}')
print(f'x_test shape: {x_test.shape}, y_test shape: {y_test.shape}')
# Out:
# x_train shape: (285662, 9), y_train shape: (285662,)
# x_test shape: (47639, 9), y_test shape: (47639,)

# %%
model_info_eksperimen = []
for model, i in zip(model_lib,model_name):
    name,f1Score, akurasi,rocAuc = result_detail(model,i)
    visual_ROC(model,i,rocAuc)
    model_info_eksperimen.append([name, f1Score, akurasi, rocAuc]) # Ini semua info yang nanti akan ditapilkan kedalam dataframe untuk setiap model
# Out:
# ...
# Model Decision Tree
# Recall		 : 0.3035318205084457
# Precision	 : 0.2902120717781403
# F1-Score	 : 0.2967225419064298
# ROC-AUC Score	 : 0.5996930489396554
# Akurasi Score	 : 0.8229811708893974
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90     41778
#            1       0.29      0.30      0.30      5861
#
#     accuracy                           0.82     47639
#    macro avg       0.60      0.60      0.60     47639
# weighted avg       0.83      0.82      0.82     47639
# ...
# Model Logistic Regression
# Recall		 : 0.0005118580447022692
# Precision	 : 0.3
# F1-Score	 : 0.0010219724067450178
# ROC-AUC Score	 : 0.5001721528722243
# Akurasi Score	 : 0.8768865845210857
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93     41778
#            1       0.30      0.00      0.00      5861
#
# ...

# %%
# Hasil info sebelumnya dimasukan kedalam data frame
df_result_eksperimen = pd.DataFrame(model_info_eksperimen, columns=['Nama_Model', 'F1_Score','Akurasi','Roc_Auc'])
df_result_eksperimen
# Out:
#                  Nama_Model  F1_Score   Akurasi   Roc_Auc
# 0             Decision Tree  0.296723  0.822981  0.599693
# 1       Logistic Regression  0.001022  0.876887  0.500172
# 2       K-Nearest Neighbors  0.047390  0.875102  0.509789
# 3  Random Forest Classifier  0.176731  0.867210  0.544234
# 4      Gaussian Naive Bayes  0.410071  0.660152  0.789076

# %%
f1Score = []
accuracy = []
rocScore = []

for i in range(len(model_info)):
  f1Score.append([model_info[i][0], model_info[i][1], model_info_eksperimen[i][1]])
  accuracy.append([model_info[i][0], model_info[i][2], model_info_eksperimen[i][2]])
  rocScore.append([model_info[i][0], model_info[i][3], model_info_eksperimen[i][3]])

df_f1Score = pd.DataFrame(f1Score, columns=['Nama_Model', 'Without_Outlier', 'With_Outlier'])
df_accuracy = pd.DataFrame(accuracy, columns=['Nama_Model', 'Without_Outlier', 'With_Outlier'])
df_roc = pd.DataFrame(rocScore, columns=['Nama_Model', 'Without_Outlier', 'With_Outlier'])

# %%
print('F1 Score')
df_f1Score
# Out:
# F1 Score
#                  Nama_Model  Without_Outlier  With_Outlier
# 0             Decision Tree         0.361617      0.296723
# 1       Logistic Regression         0.003729      0.001022
# 2       K-Nearest Neighbors         0.029647      0.047390
# 3  Random Forest Classifier         0.216708      0.176731
# 4      Gaussian Naive Bayes         0.421454      0.410071

# %%
fig, ax1 = plt.subplots(figsize=(15, 5))
tidy = df_f1Score.melt(id_vars='Nama_Model').rename(columns=str.title)
sns.barplot(x='Nama_Model', y='Value', hue='Variable',palette='viridis', data=tidy, ax=ax1).set_title('Komparasi F1-Score')
sns.despine(fig)

# %%
print('Akurasi Score')
df_accuracy
# Out:
# Akurasi Score
#                  Nama_Model  Without_Outlier  With_Outlier
# 0             Decision Tree         0.788849      0.822981
# 1       Logistic Regression         0.876614      0.876887
# 2       K-Nearest Neighbors         0.874955      0.875102
# 3  Random Forest Classifier         0.853565      0.867210
# 4      Gaussian Naive Bayes         0.684586      0.660152

# %%
fig, ax1 = plt.subplots(figsize=(15, 5))
tidy = df_accuracy.melt(id_vars='Nama_Model').rename(columns=str.title)
sns.barplot(x='Nama_Model', y='Value', hue='Variable',palette='viridis', data=tidy, ax=ax1).set_title('Komparasi Accuracy')
sns.despine(fig)

# %%
print('ROC-AUC Score')
df_roc
# Out:
# ROC-AUC Score
#                  Nama_Model  Without_Outlier  With_Outlier
# 0             Decision Tree         0.658709      0.599693
# 1       Logistic Regression         0.500603      0.500172
# 2       K-Nearest Neighbors         0.505525      0.509789
# 3  Random Forest Classifier         0.557430      0.544234
# 4      Gaussian Naive Bayes         0.791712      0.789076

# %%
fig, ax1 = plt.subplots(figsize=(15, 5))
tidy = df_roc.melt(id_vars='Nama_Model').rename(columns=str.title)
sns.barplot(x='Nama_Model', y='Value', hue='Variable',palette='viridis', data=tidy, ax=ax1).set_title('Komparasi ROC-AUC Score')
sns.despine(fig)
